# %%
import numpy as np
import pandas as pd

# %%
lending_data = pd.read_csv('F:\Aegis - lectures\project_session_bhavik_gandhi\project_1\LoanStats3c.csv')
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (0,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
lending_data.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    10400.0      10400.0          10400.0   36 months
# 1  NaN        NaN    15000.0      15000.0          15000.0   60 months
# 2  NaN        NaN     9600.0       9600.0           9600.0   36 months
# 3  NaN        NaN     7650.0       7650.0           7650.0   36 months
# 4  NaN        NaN    12800.0      12800.0          12800.0   60 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0    6.99%       321.08     A        A3       ...
# 1   12.39%       336.64     C        C1       ...
# 2   13.66%       326.53     C        C3       ...
# 3   13.66%       260.20     C        C3       ...
# 4   17.14%       319.08     D        D4       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# ...

# %%
#lending_data.columns.values

# %%
#lending_new1 = lending_data[['int_rate','loan_amnt','funded_amnt','funded_amnt_inv','installment','annual_inc','revol_util','purpose',
#                             'dti','delinq_2yrs','inq_last_6mths','term','home_ownership','loan_status','earliest_cr_line',
#                             'open_acc','pub_rec','revol_bal','total_acc','out_prncp','out_prncp_inv','total_pymnt','issue_d',
#                             'total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee',
#                             'last_pymnt_amnt','collections_12_mths_ex_med','verification_status']]
#lending_new1 = lending_data[['loan_amnt','funded_amnt','term','funded_amnt_inv','int_rate','installment','annual_inc','revol_util','purpose',
#                            'dti','delinq_2yrs','inq_last_6mths','mths_since_last_delinq','home_ownership','loan_status','mths_since_last_record',
#                            'open_acc','pub_rec','revol_bal','total_acc','out_prncp','out_prncp_inv','total_pymnt',
#                            'total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee','recoveries',
#                            'collection_recovery_fee','last_pymnt_amnt','collections_12_mths_ex_med','verification_status',
#                            'mths_since_last_major_derog']] 
lending_new1 = lending_data[['loan_amnt','funded_amnt','term','funded_amnt_inv','int_rate','installment','annual_inc','revol_util','purpose',
                            'dti','delinq_2yrs','inq_last_6mths','mths_since_last_delinq','home_ownership','loan_status','mths_since_last_record',
                            'open_acc','pub_rec','revol_bal','total_acc','out_prncp','out_prncp_inv','total_pymnt',
                            'total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee','recoveries',
                            'collection_recovery_fee','last_pymnt_amnt','collections_12_mths_ex_med','verification_status',
                            'mths_since_last_major_derog','acc_now_delinq','tot_coll_amt','tot_cur_bal','total_rev_hi_lim','acc_open_past_24mths',
                             'avg_cur_bal','bc_open_to_buy','bc_util','chargeoff_within_12_mths','delinq_amnt','mo_sin_old_rev_tl_op','mo_sin_rcnt_rev_tl_op','mo_sin_rcnt_tl','mort_acc',
                            'mths_since_recent_bc','num_accts_ever_120_pd','num_actv_bc_tl','num_actv_rev_tl',
                            'num_bc_sats','num_bc_tl','num_il_tl','num_op_rev_tl','num_rev_accts','num_rev_tl_bal_gt_0','num_sats','num_tl_120dpd_2m',
                             'num_tl_30dpd','num_tl_90g_dpd_24m','num_tl_op_past_12m','pct_tl_nvr_dlq','percent_bc_gt_75',
                            'pub_rec_bankruptcies','tax_liens','tot_hi_cred_lim','total_bal_ex_mort','total_bc_limit','total_il_high_credit_limit']]

# %%
lending_new1.shape
# Out:
# (235633, 70)

# %%
lending_new1.shape
# Out:
# (235633, 70)

# %%
#%%
#removing percent symbol 
cols =['int_rate','revol_util']
lending_new1[cols] = lending_new1[cols].replace({'%': ''}, regex=True)
lending_new1.head(10)
#%%
#converting into numeric
lending_new1 = lending_new1.astype({"int_rate": float, "revol_util": float})
#%%
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\pandas\core\frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
lending_new1 = lending_new1.iloc[:-4,:]
lending_new2 = lending_new1.copy()

# %%
lending_new1.describe()
# Out:
#            loan_amnt    funded_amnt  funded_amnt_inv       int_rate  \
# count  235629.000000  235629.000000    235629.000000  235629.000000
# mean    14870.156793   14870.156793     14865.334169      13.769465
# std      8438.318193    8438.318193      8435.524995       4.326218
# min      1000.000000    1000.000000       950.000000       6.000000
# 25%      8325.000000    8325.000000      8325.000000      10.990000
# 50%     13000.000000   13000.000000     13000.000000      13.650000
# 75%     20000.000000   20000.000000     20000.000000      16.290000
# max     35000.000000   35000.000000     35000.000000      26.060000
#
#          installment    annual_inc     revol_util            dti  \
# count  235629.000000  2.356290e+05  235504.000000  235629.000000
# mean      442.454925  7.485415e+04      55.685369      18.040770
# std       245.041761  5.554753e+04      23.100399       8.023002
# min        23.360000  3.000000e+03       0.000000       0.000000
# ...

# %%
lending_new1.count()
# Out:
# loan_amnt                     235629
# funded_amnt                   235629
# term                          235629
# funded_amnt_inv               235629
# int_rate                      235629
# installment                   235629
# annual_inc                    235629
# revol_util                    235504
# purpose                       235629
# dti                           235629
# delinq_2yrs                   235629
# inq_last_6mths                235629
# mths_since_last_delinq        119748
# home_ownership                235629
# loan_status                   235629
# mths_since_last_record         41524
# open_acc                      235629
# pub_rec                       235629
# revol_bal                     235629
# total_acc                     235629
# out_prncp                     235629
# out_prncp_inv                 235629
# total_pymnt                   235629
# total_pymnt_inv               235629
# total_rec_prncp               235629
# ...

# %%
lending_new1.isnull().sum()
# Out:
# loan_amnt                          0
# funded_amnt                        0
# term                               0
# funded_amnt_inv                    0
# int_rate                           0
# installment                        0
# annual_inc                         0
# revol_util                       125
# purpose                            0
# dti                                0
# delinq_2yrs                        0
# inq_last_6mths                     0
# mths_since_last_delinq        115881
# home_ownership                     0
# loan_status                        0
# mths_since_last_record        194105
# open_acc                           0
# pub_rec                            0
# revol_bal                          0
# total_acc                          0
# out_prncp                          0
# out_prncp_inv                      0
# total_pymnt                        0
# total_pymnt_inv                    0
# total_rec_prncp                    0
# ...

# %%
lending_new1[['revol_util']] = lending_new1[['revol_util']].fillna(0)
lending_new1.loc[lending_new1['revol_util'] > 100,'revol_util'] = 100
#lending_new1.revol_util[lending_new1.revol_util > 100] = 100

# %%
lending_new1.revol_util.describe()
# Out:
# count    235629.000000
# mean         55.636652
# std          23.023265
# min           0.000000
# 25%          38.900000
# 50%          56.300000
# 75%          73.400000
# max         100.000000
# Name: revol_util, dtype: float64

# %%
lending_new1.isnull().sum()
# Out:
# loan_amnt                          0
# funded_amnt                        0
# term                               0
# funded_amnt_inv                    0
# int_rate                           0
# installment                        0
# annual_inc                         0
# revol_util                         0
# purpose                            0
# dti                                0
# delinq_2yrs                        0
# inq_last_6mths                     0
# mths_since_last_delinq        115881
# home_ownership                     0
# loan_status                        0
# mths_since_last_record        194105
# open_acc                           0
# pub_rec                            0
# revol_bal                          0
# total_acc                          0
# out_prncp                          0
# out_prncp_inv                      0
# total_pymnt                        0
# total_pymnt_inv                    0
# total_rec_prncp                    0
# ...

# %%
lending_new1['term'].head()
lending_new1['term'] = lending_new1['term'].str.rstrip(' months')
lending_new1[['term']] = lending_new1[['term']].astype(int)

# %%
#lending_new1['earliest_cr_line'].head()
#lending_new1['earliest_cr_line'] = pd.to_datetime(lending_new1['earliest_cr_line'],format = '%b-%y')
#lending_new1['issue_d'] = pd.to_datetime(lending_new1['issue_d'],format = '%b-%y')
#lending_new1['NOOfDays'] = lending_new1['issue_d'].sub(lending_new1['earliest_cr_line']).dt.days
#lending_new1['NOOfDays'].head()

# %%
lending_new1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235629 entries, 0 to 235628
# Data columns (total 70 columns):
# loan_amnt                      235629 non-null float64
# funded_amnt                    235629 non-null float64
# term                           235629 non-null int32
# funded_amnt_inv                235629 non-null float64
# int_rate                       235629 non-null float64
# installment                    235629 non-null float64
# annual_inc                     235629 non-null float64
# revol_util                     235629 non-null float64
# purpose                        235629 non-null object
# dti                            235629 non-null float64
# delinq_2yrs                    235629 non-null float64
# inq_last_6mths                 235629 non-null float64
# mths_since_last_delinq         119748 non-null float64
# home_ownership                 235629 non-null object
# loan_status                    235629 non-null object
# ...

# %%
lending_new1.corr().style.background_gradient(cmap = 'coolwarm').set_precision(2)
#print(len(lending_new1.columns.values))
# Out:
# <style  type="text/css" >
#     #T_d16c2a3a_63ee_11e9_97ab_1c394735d607row0_col0 {
#             background-color:  #b40426;
#         }    #T_d16c2a3a_63ee_11e9_97ab_1c394735d607row0_col1 {
#             background-color:  #b40426;
#         }    #T_d16c2a3a_63ee_11e9_97ab_1c394735d607row0_col2 {
#             background-color:  #cad8ef;
#         }    #T_d16c2a3a_63ee_11e9_97ab_1c394735d607row0_col3 {
#             background-color:  #b40426;
#         }    #T_d16c2a3a_63ee_11e9_97ab_1c394735d607row0_col4 {
#             background-color:  #a3c2fe;
#         }    #T_d16c2a3a_63ee_11e9_97ab_1c394735d607row0_col5 {
#             background-color:  #c43032;
#         }    #T_d16c2a3a_63ee_11e9_97ab_1c394735d607row0_col6 {
#             background-color:  #dcdddd;
#         }    #T_d16c2a3a_63ee_11e9_97ab_1c394735d607row0_col7 {
#             background-color:  #c1d4f4;
#         }    #T_d16c2a3a_63ee_11e9_97ab_1c394735d607row0_col8 {
#             background-color:  #7a9df8;
# ...

# %%
#lending_new1.info()

# %%
#colmn = ['loan_amnt','funded_amnt','installment','out_prncp','issue_d','earliest_cr_line','total_pymnt_inv','total_rec_prncp','out_prncp_inv']
#colmn = ['loan_amnt','funded_amnt','installment','out_prncp','total_pymnt_inv','total_rec_prncp','out_prncp_inv',
#        'mths_since_last_major_derog','mths_since_last_record','mths_since_last_delinq']
colmn = ['loan_amnt','funded_amnt','installment','out_prncp','total_pymnt_inv','total_rec_prncp','out_prncp_inv',
        'mths_since_last_major_derog','mths_since_last_record','mths_since_last_delinq','num_sats','bc_util',
        'collection_recovery_fee','total_rev_hi_lim','avg_cur_bal','tot_hi_cred_lim','num_actv_rev_tl',
        'num_tl_120dpd_2m','tot_coll_amt','num_bc_tl','num_il_tl','num_rev_tl_bal_gt_0']

# %%
lending_new1.corr().style.background_gradient(cmap = 'coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_d4ed4866_63ee_11e9_ba7a_1c394735d607row0_col0 {
#             background-color:  #b40426;
#         }    #T_d4ed4866_63ee_11e9_ba7a_1c394735d607row0_col1 {
#             background-color:  #b40426;
#         }    #T_d4ed4866_63ee_11e9_ba7a_1c394735d607row0_col2 {
#             background-color:  #cad8ef;
#         }    #T_d4ed4866_63ee_11e9_ba7a_1c394735d607row0_col3 {
#             background-color:  #b40426;
#         }    #T_d4ed4866_63ee_11e9_ba7a_1c394735d607row0_col4 {
#             background-color:  #a3c2fe;
#         }    #T_d4ed4866_63ee_11e9_ba7a_1c394735d607row0_col5 {
#             background-color:  #c43032;
#         }    #T_d4ed4866_63ee_11e9_ba7a_1c394735d607row0_col6 {
#             background-color:  #dcdddd;
#         }    #T_d4ed4866_63ee_11e9_ba7a_1c394735d607row0_col7 {
#             background-color:  #c1d4f4;
#         }    #T_d4ed4866_63ee_11e9_ba7a_1c394735d607row0_col8 {
#             background-color:  #7a9df8;
# ...

# %%
lending_new1.drop(colmn,axis=1,inplace=True)

# %%
column1 = ['total_pymnt','num_op_rev_tl','acc_now_delinq','bc_open_to_buy','acc_open_past_24mths','num_actv_bc_tl',
           'num_bc_sats','num_rev_accts','num_tl_30dpd','num_tl_op_past_12m','tax_liens','total_bc_limit']

# %%
lending_new1.drop(column1,axis=1,inplace=True)

# %%
#lending_new1.corr().style.background_gradient(cmap = 'coolwarm').set_precision(2)

# %%
lending_new1 = pd.get_dummies(data=lending_new1,columns= ['home_ownership','verification_status','purpose','loan_status'])

# %%
lending_new1 = lending_new1.dropna(axis = 0)

# %%
y = lending_new1['int_rate']
x = lending_new1.drop('int_rate',axis = 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 100)

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = model1.predict(x_test)
y_pred1 = model1.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score, mean_absolute_error
Variance_score = explained_variance_score(y_test, y_pred)
Variance_score1 = explained_variance_score(y_train, y_pred1)
print ('Variance score_train : %.2f' %Variance_score1)
print('Variance score_test : %.2f' %Variance_score)


#Mean Absolute Error
MAE = mean_absolute_error(y_test, y_pred)
MAE1 = mean_absolute_error(y_train, y_pred1)
print ('Mean Absolute Error_train : %.2f' %MAE1)
print ('Mean Absolute Error_test : %.2f' %MAE)


#Root Mean Squared Error
RMSE = mean_squared_error(y_test,y_pred)**0.5
RMSE1 = mean_squared_error(y_train,y_pred1)**0.5
print ('Mean Squared Error_train : %.2f' %RMSE1)
print ('Mean Squared Error_test : %.2f' %RMSE)
#R² score, the coefficient of determination
r2s = r2_score(y_test, y_pred)
r3s = r2_score(y_train,y_pred1)
print ('R2  score train: %.2f' %r3s)
print ('R2  score test: %.2f' %r2s)
# Out:
# Variance score_train : 0.60
# Variance score_test : 0.60
# Mean Absolute Error_train : 2.10
# Mean Absolute Error_test : 2.11
# Mean Squared Error_train : 2.72
# Mean Squared Error_test : 2.72
# R2  score train: 0.60
# R2  score test: 0.60

# %%
print(model1.score(x_train,y_train))
print(model1.score(x_test,y_test))
# Out:
# 0.6040471236564184
# 0.6046399911762388

# %%
from sklearn.linear_model import lasso
lasso = lasso()
parameters = {'alpha' : [1e-15,1e-10.1e-8,1e-4,1e-3,1e-2,1,5,10,20]}

# %%
import seaborn as sns 

sns.residplot(y_test,y_pred, lowess=True, color="g")

# %%
import matplotlib.pyplot as plt
a = y_pred - y_test
b = y_pred1 - y_train
plt.hist(a)
plt.show()

# %%
plt.hist(b)
plt.show()

# %%
plt.boxplot(a)
plt.show()

# %%
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
model1=sm.OLS(y_train,x_train)

result=model1.fit()

print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               int_rate   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                     4937.
# Date:                Sun, 21 Apr 2019   Prob (F-statistic):               0.00
# Time:                        10:05:13   Log-Likelihood:            -4.2306e+05
# No. Observations:              174804   AIC:                         8.462e+05
# Df Residuals:                  174749   BIC:                         8.468e+05
# Df Model:                          54
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
print(min(lending_new1['int_rate']))
print(max(lending_new1['int_rate']))
# Out:
# 6.0
# 26.06

# %%
#plt.bar(x= lending_new2['home_ownership'],height = lending_new2['loan_amnt'])
#plt.show()
print(min(lending_new2['loan_amnt']))
print(max(lending_new2['loan_amnt']))
x = lending_new2['home_ownership'].unique()
y = lending_new2['loan_amnt']
#plt.bar(x,y)
#plt.show()

a = lending_new2[['loan_amnt','home_ownership']].groupby('home_ownership').sum()
a
# Out:
# 1000.0
# 35000.0
#                    loan_amnt
# home_ownership
# ANY             5.000000e+03
# MORTGAGE        1.987983e+09
# OWN             3.247404e+08
# RENT            1.191111e+09

# %%
import matplotlib.pyplot as plt
bins = np.arange(0,35000,5000)
#print(bins)
plt.hist(lending_new2['loan_amnt'],bins)
# Out:
# (array([18441., 52293., 59011., 40571., 30378., 20952.]),
#  array([    0,  5000, 10000, 15000, 20000, 25000, 30000]),
#  <a list of 6 Patch objects>)

# %%
x,y = np.unique(lending_new2['loan_status'],return_counts=True)
print(x)
print(y)
plt.bar(x,y)
plt.show()
# Out:
# ['Charged Off' 'Current' 'Default' 'Fully Paid' 'In Grace Period'
#  'Late (16-30 days)' 'Late (31-120 days)']
# [ 41161  11919      1 181941    200     73    334]

# %%
x,y = np.unique(lending_new2['int_rate'],return_counts=True)
plt.bar(x,y)
plt.show()

# %%
#plt.boxplot(lending_new2['dti'],by=lending_new2['int_rate'])
#plt.show()
#lending_new2.boxplot(column='dti',by= 'int_rate')
print(lending_data[['dti','grade']].groupby('grade').mean())
print(lending_data[['dti','sub_grade']].groupby('sub_grade').mean())
# Out:
#              dti
# grade
# A      15.817832
# B      17.195035
# C      18.383129
# D      19.427035
# E      20.000147
# F      19.446466
# G      19.279181
#                  dti
# sub_grade
# A1         14.849944
# A2         15.381656
# A3         15.967343
# A4         15.967747
# A5         16.284645
# B1         16.730820
# B2         16.934910
# B3         17.202535
# B4         17.352403
# B5         17.622927
# C1         17.965990
# C2         18.249286
# C3         18.299890
# C4         18.628224
# C5         18.828388
# D1         19.196263
# D2         19.372668
# D3         19.450776
# D4         19.457367
# D5         19.844637
# E1         19.859513
# E2         19.746943
# E3         20.256051
# E4         20.272425
# E5         20.061805
# F1         19.687566
# F2         19.854303
# F3         19.358350
# F4         18.757573
# F5         19.078179
# G1         20.051879
# G2         19.097330
# G3         19.068393
# G4         18.670981
# G5         18.641840

# %%
odr = sorted(lending_data['grade'][:-4].unique())
print(odr)
import seaborn as sns
pot1 = sns.boxplot(x=lending_data["grade"][:-4], y=lending_new2["int_rate"],
            palette="hls",order = odr)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
odr = sorted(lending_data['grade'][:-4].unique())
print(odr)
pot2 = sns.boxplot(x=lending_data["grade"][:-4], y=lending_new2["dti"],
            palette="hls",order = odr)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
plt.scatter(lending_new1.dti[:5000],lending_new1.int_rate[:5000])
plt.show()

# %%
plt.scatter(lending_new1.revol_util,lending_new1.int_rate)
plt.show()

# %%
plt.scatter(lending_new1.funded_amnt_inv,lending_new1.int_rate)
plt.show()

# %%
plt.scatter(lending_new1.annual_inc,lending_new1.int_rate)
plt.show()

# %%
plt.scatter(lending_new1.term,lending_new1.int_rate)
plt.show()

# %%
plt.scatter(lending_new1.inq_last_6mths,lending_new1.int_rate)
plt.show()

# %%
plt.scatter(lending_new1.open_acc,lending_new1.int_rate)
plt.show()

# %%
plt.scatter(lending_new1.pub_rec,lending_new1.int_rate)
plt.show()

# %%
plt.scatter(lending_new1.revol_bal,lending_new1.int_rate)
plt.show()

# %%
plt.scatter(lending_new1.total_rec_late_fee,lending_new1.int_rate)
plt.show()

# %%
plt.scatter(lending_new1.recoveries,lending_new1.int_rate)
plt.show()

# %%
x = sorted(lending_new2['delinq_2yrs'].unique())
import seaborn as sns
pot = sns.boxplot(x="delinq_2yrs", y="int_rate", data=lending_new2,
            palette="hls",order= x)
pot.set_xticklabels(x,rotation = 45)
#plt.setp(pot.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, '0.0'),
#  Text(0, 0, '1.0'),
#  Text(0, 0, '2.0'),
#  Text(0, 0, '3.0'),
#  Text(0, 0, '4.0'),
#  Text(0, 0, '5.0'),
#  Text(0, 0, '6.0'),
#  Text(0, 0, '7.0'),
#  Text(0, 0, '8.0'),
#  Text(0, 0, '9.0'),
#  Text(0, 0, '10.0'),
#  Text(0, 0, '11.0'),
#  Text(0, 0, '12.0'),
#  Text(0, 0, '13.0'),
#  Text(0, 0, '14.0'),
#  Text(0, 0, '15.0'),
#  Text(0, 0, '16.0'),
#  Text(0, 0, '17.0'),
#  Text(0, 0, '18.0'),
#  Text(0, 0, '19.0'),
#  Text(0, 0, '21.0'),
#  Text(0, 0, '22.0')]

# %%
odr = sorted(lending_data['sub_grade'][:-4].unique())
print(odr)
pot2 = sns.boxplot(x=lending_data["sub_grade"][:-4], y=lending_new2["dti"],
            palette="hls",order = odr)
# Out:
# ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4', 'G5']

# %%
odr = sorted(lending_data['sub_grade'][:-4].unique())
print(odr)
pot2 = sns.boxplot(x=lending_data["sub_grade"][:-4], y=lending_new2["open_acc"],
            palette="hls",order = odr)
# Out:
# ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4', 'G5']
